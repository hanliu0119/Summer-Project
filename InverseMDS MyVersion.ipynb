# %% [markdown]
# # Preprocess for Sliders

# %%
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import ipywidgets as ipywidgets
df = pd.read_csv("~/Desktop/Thesis/InfoVis_Fall_2015_Survey.csv")
df = df.set_index('Name')
dataHD = df.copy()
for column in dataHD.columns:
    dataHD[column] = (dataHD[column]-dataHD[column].mean())/dataHD[column].std()
dataHD.head()
# Out:
#                  Age      Shoe  Siblings  SleepHours  Temperature      Pets  \
# Name
# Sangeetha  -0.404611 -1.530706 -0.261505    0.095682     0.293482 -0.502268
# Gracie     -0.595356 -0.737303  0.601461    0.095682    -0.429272  1.593402
# Testing123 -0.213866  0.585034 -0.261505   -2.430316     0.438033 -2.178804
# Guangyue    0.549115 -0.208368 -1.124471    0.095682     0.510308  0.450309
# Harsh      -0.786101 -0.472836 -0.261505    1.358681     0.654859  0.640825
#
#             Extrovert      Cook    Spicey  Restaurants  ...    PCvMac  \
# Name                                                    ...
# Sangeetha   -0.187416  0.141207  0.893553    -0.897742  ...  0.447088
# Gracie      -1.917407 -0.226675 -1.042152    -1.023808  ... -0.184273
# Testing123   1.758824 -0.226675  0.409626    -0.771676  ...  1.809500
# Guangyue    -0.403665 -1.044190 -1.493817     0.615049  ...  0.314170
# Harsh        1.110078  0.590841  1.054862    -1.023808  ...  0.314170
#
#                   CS     Books  DistanceBorn  Countries    States  \
# Name
# Sangeetha   0.903888  0.835355      0.989008  -0.352654 -0.828475
# Gracie      0.903888  2.071532     -1.177020   0.270788  0.240177
# Testing123  0.378742 -0.153586      0.715399  -0.352654 -0.917529
# Guangyue   -1.721843 -0.400821      0.564678  -0.352654 -0.116040
# Harsh      -0.146404 -0.400821      1.855787  -0.768282 -0.917529
#
#             PlacesLived   Camping  JobYears  Publications
# Name
# Sangeetha     -0.594105 -0.381897 -0.443943     -0.271287
# Gracie        -0.594105 -0.331886  0.061234     -0.099124
# Testing123    -0.594105 -0.381897 -0.443943     -0.099124
# Guangyue      -0.594105 -0.465247  0.818999     -0.156512
# Harsh         -0.932130 -0.465247 -0.949120     -0.213900
#
# [5 rows x 25 columns]

# %%
Age = ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=0.5)
Age
# Out:
# FloatSlider(value=0.5, max=1.0, step=0.05)

# %%
#val = 1/len(dataHD.columns)
val = 0.5
Age = ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
Shoe = ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
Siblings = ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
SleepHours = ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
Temperature = ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
Pets = ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
Extrovert = ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
Cook = ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
Spicey = ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
Restaurants = ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
SpendMoney = ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
PhoneMinutes = ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
PhoneApps=ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
Photos=ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
Facebook= ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
PCvMac=ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
CS=ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
Books=ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
DistanceBorn=ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
Countries=ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
States=ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
PlacesLived=ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
Camping=ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
JobYears=ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)
Publications=ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.05, value=val)

# %% [markdown]
# # MDS Function

# %%
import sklearn.metrics.pairwise
import sklearn.manifold

def cal_distance(dataHD):
    distHD = sklearn.metrics.pairwise.manhattan_distances(dataHD)
    distHD = pd.DataFrame(distHD, columns=dataHD.index, 
                          index=dataHD.index)
    # set up the parameters:
    mds = sklearn.manifold.MDS(n_components=2, dissimilarity='precomputed', n_init=100, max_iter=1000)

    # reduction algorithm happens here:
    data2D = mds.fit_transform(distHD)
    data2D = pd.DataFrame(data2D, columns=['x','y'], index=dataHD.index)
    return data2D

# %% [markdown]
# # Interactive Plot with Sliders

# %%
# %matplotlib notebook
#!/usr/bin/env python2
# -*- coding: utf-8 -*-
"""
Created on Sat Mar  4 10:57:02 2017

@author: Nathan Wycoff
"""
    
from ipywidgets import interactive
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

class DraggablePoints(object):
    def __init__(self, artists, tolerance=5):
        for artist in artists:
            artist.set_picker(tolerance)
        self.artists = artists
        self.currently_dragging = False
        self.current_artist = None
        self.offset = (0, 0)

        for canvas in set(artist.figure.canvas for artist in self.artists):
            canvas.mpl_connect('button_press_event', self.on_press)
            canvas.mpl_connect('button_release_event', self.on_release)
            canvas.mpl_connect('pick_event', self.on_pick)
            canvas.mpl_connect('motion_notify_event', self.on_motion)

    def on_press(self, event):
        self.currently_dragging = True

    def on_release(self, event):
        self.currently_dragging = False
        self.current_artist = None

    def on_pick(self, event):
        if self.current_artist is None:
            self.current_artist = event.artist
            x0, y0 = event.artist.center
            x1, y1 = event.mouseevent.xdata, event.mouseevent.ydata
            self.offset = (x0 - x1), (y0 - y1)

    def on_motion(self, event):
        if not self.currently_dragging:
            return
        if self.current_artist is None:
            return
        dx, dy = self.offset
        self.current_artist.center = event.xdata + dx, event.ydata + dy
        self.current_artist.figure.canvas.draw()

def plot(Age,Shoe,Siblings,SleepHours,Temperature,Pets,Extrovert,Cook,Spicey,Restaurants,SpendMoney,PhoneMinutes,PhoneApps,Photos,Facebook,PCvMac,CS,Books,DistanceBorn,Countries,States,PlacesLived,Camping,JobYears,Publications):
    weight_list = [Age,Shoe,Siblings,SleepHours,Temperature,Pets,Extrovert,Cook,Spicey,Restaurants,SpendMoney,PhoneMinutes,PhoneApps,Photos,Facebook,PCvMac,CS,Books,DistanceBorn,Countries,States,PlacesLived,Camping,JobYears,Publications]
    weight_list = [x/10 for x in weight_list]
    df = pd.read_csv("~/Desktop/Thesis/InfoVis_Fall_2015_Survey.csv")
    df = df.set_index('Name')
    dataHD = df.copy()
    for column in dataHD.columns:
        dataHD[column] = (dataHD[column]-dataHD[column].mean())/dataHD[column].std()
    # apply weights to the data
    for i in range(len(dataHD.columns.tolist())):
        dataHD.iloc[:, i] = [x*weight_list[i] for x in dataHD.iloc[:, i]]
    
    # calculate distance and return points
    data2D = cal_distance(dataHD)
    # Data
    x = data2D['x'].tolist()
    y = data2D['y'].tolist()
    X = zip(x, y)
    print(X)
    labels = data2D.index.values.tolist()
    # Create the figure and axes objects
    fig, ax = plt.subplots(1, figsize=(10, 6))
    fig.suptitle('Distribution of Students')
    ax.scatter(x, y,
           color="blue",  # Color of the dots
           s=100,         # Size of the dots
           alpha=0.5,     # Alpha of the dots
           linewidths=1)  # Size of edge around the dots

    # Add the participant names as text labels for each point
    for x_pos, y_pos, label in zip(x, y, labels):
        ax.annotate(label,             # The label for this point
                xy=(x_pos, y_pos), # Position of the corresponding point
                xytext=(7, 0),     # Offset text by 7 points to the right
                textcoords='offset points', # tell it to use offset points
                ha='left',         # Horizontally aligned to the left
                va='center')       # Vertical alignment is centered
    # Show the plot
    plt.show()
    

interactive_plot = interactive(plot, Age=Age,Shoe=Shoe,Siblings=Siblings,SleepHours=SleepHours,Temperature=Temperature,
                               Pets=Pets,Extrovert=Extrovert,Cook=Cook,Spicey=Spicey,Restaurants=Restaurants,
                               SpendMoney=SpendMoney,PhoneMinutes=PhoneMinutes,PhoneApps=PhoneApps,Photos=Photos,
                               Facebook=Facebook,PCvMac=PCvMac,CS=CS,Books=Books,DistanceBorn=DistanceBorn,Countries=Countries,
                               States=States,PlacesLived=PlacesLived,Camping=Camping,JobYears=JobYears,Publications=Publications)
output = interactive_plot.children[-1]
#output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.5, description='Age', max=1.0, step=0.05), FloatSlider(value=0.5, de…

# %% [markdown]
# # Draggable Plot with Updated Weights

# %%
# %matplotlib notebook
#!/usr/bin/env python2
# -*- coding: utf-8 -*-
"""
Created on Sat Mar  4 10:57:02 2017

@author: Nathan Wycoff
"""

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

class DraggablePoints(object):
    def __init__(self, artists, tolerance=5):
        for artist in artists:
            artist.set_picker(tolerance)
        self.artists = artists
        self.currently_dragging = False
        self.current_artist = None
        self.offset = (0, 0)

        for canvas in set(artist.figure.canvas for artist in self.artists):
            canvas.mpl_connect('button_press_event', self.on_press)
            canvas.mpl_connect('button_release_event', self.on_release)
            canvas.mpl_connect('pick_event', self.on_pick)
            canvas.mpl_connect('motion_notify_event', self.on_motion)

    def on_press(self, event):
        self.currently_dragging = True

    def on_release(self, event):
        self.currently_dragging = False
        self.current_artist = None
        self.signal.updatedSignal.emit(str(self.point.newYcoordinate))
        self.dragValue.signal.updatedSignal.connect(self.updatedValue)

    def on_pick(self, event):
        if self.current_artist is None:
            self.current_artist = event.artist
            x0, y0 = event.artist.center
            x1, y1 = event.mouseevent.xdata, event.mouseevent.ydata
            self.offset = (x0 - x1), (y0 - y1)

    def on_motion(self, event):
        if not self.currently_dragging:
            return
        if self.current_artist is None:
            return
        dx, dy = self.offset
        self.current_artist.center = event.xdata + dx, event.ydata + dy
        self.current_artist.figure.canvas.draw()

#Generate some data
df = pd.read_csv("~/Desktop/Thesis/InfoVis_Fall_2015_Survey.csv")
df = df.set_index('Name')
dataHD = df.copy()
weight_list = [Age.value,Shoe.value,Siblings.value,SleepHours.value,Temperature.value,Pets.value,Extrovert.value,
               Cook.value,Spicey.value,Restaurants.value,SpendMoney.value,PhoneMinutes.value,PhoneApps.value,
               Photos.value,Facebook.value,PCvMac.value,CS.value,Books.value,DistanceBorn.value,Countries.value,
               States.value,PlacesLived.value,Camping.value,JobYears.value,Publications.value]
weight_list = [x/sum(weight_list) for x in weight_list]
print(weight_list)
for column in dataHD.columns:
    dataHD[column] = (dataHD[column]-dataHD[column].mean())/dataHD[column].std()
# apply weights to the data

for i in range(len(dataHD.columns.tolist())):
    dataHD.iloc[:, i] = [x*weight_list[i] for x in dataHD.iloc[:, i]]    
# calculate distance and return points
data2D = cal_distance(dataHD)

# Data
x = data2D['x'].tolist()
y = data2D['y'].tolist()
X = np.column_stack((x, y))
labels = data2D.index.values.tolist()
    
#Set up the axes
fig, ax = plt.subplots()
ax.set(xlim=[min(X[:,0]) - 0.2, max(X[:,0]) + 0.7], ylim=[min(X[:,1]) - 0.2, max(X[:,1]) + 0.2])
labels = data2D.index.values.tolist()

print(labels)    
# Create the figure and axes objects
fig.suptitle('Distribution of Students')

    # Add the participant names as text labels for each point
for x_pos, y_pos, label in zip(x, y, labels):
    ax.annotate(label,             # The label for this point
                xy=(x_pos, y_pos), # Position of the corresponding point
                xytext=(5, 3),     # Offset text by 7 points to the right
                textcoords='offset points', # tell it to use offset points
                ha='left',         # Horizontally aligned to the left
                va='center')       # Vertical alignment is centered
#Prep our circles
circles = [patches.Circle((xy[0], xy[1]), 0.03, alpha = 1) for i, xy in enumerate(X)]
for circ in circles:
    #print(circ.center)
    ax.add_patch(circ)
dr = DraggablePoints(circles)
#print(dr)

#Make the plot!
plt.show()
# Out:
# [0.05725190839694656, 0.011450381679389313, 0.06106870229007634, 0.05725190839694656, 0.03816793893129771, 0.03816793893129771, 0.03816793893129771, 0.03816793893129771, 0.03816793893129771, 0.03816793893129771, 0.03816793893129771, 0.03816793893129771, 0.03816793893129771, 0.03816793893129771, 0.03816793893129771, 0.03816793893129771, 0.03816793893129771, 0.03816793893129771, 0.03816793893129771, 0.03816793893129771, 0.05343511450381679, 0.03816793893129771, 0.011450381679389313, 0.03816793893129771, 0.06106870229007634]
# <img src="data:image/png;base64,..." width="640">
# ['Sangeetha', 'Gracie', 'Testing123', 'Guangyue', 'Harsh', 'Peng', 'Anonymous1', 'Ambika', 'Shahin', 'Jagathshree', 'Anonymous2', 'Audrey', 'Jing', 'Abhishek', 'Gustavo', 'Anonymous3', 'Andrew', 'Michelle', 'T.C.', 'Anonymous4', 'Rachel', 'Rathna', 'Anonymous5', 'Radha', 'Taylor', 'Adam', 'Moeti', 'Tomilayo', 'Derek', 'Radha', 'Dave', 'Tianyi', 'Chris']

# %% [markdown]
# # Retrieve Updated Coordinates

# %%
new_x = []
new_y = []
for circ in circles:
    new_x += [circ.center[0]]
    new_y += [circ.center[1]]
    ax.add_patch(circ)
updated_coordinates = np.column_stack((new_x, new_y))
for i in range(len(X)):
    print("Old:", X[i], "   New:",updated_coordinates[i])
# Out:
# Old: [0.08632341 0.35551557]    New: [-0.14756576  0.34678094]
# Old: [-0.5173464  -0.35186534]    New: [-0.5173464  -0.35186534]
# Old: [0.74281753 0.31352522]    New: [0.74281753 0.31352522]
# Old: [ 0.34396698 -0.39766358]    New: [ 0.08832068 -0.70337569]
# Old: [0.29448676 0.53496828]    New: [0.29448676 0.53496828]
# Old: [ 0.30609215 -0.1710562 ]    New: [ 0.30609215 -0.1710562 ]
# Old: [0.3087771  0.96039203]    New: [0.77655544 0.87304572]
# Old: [0.54280356 0.49687599]    New: [0.54280356 0.49687599]
# Old: [ 0.31222245 -0.67796952]    New: [ 0.74192582 -1.20204742]
# Old: [0.16058647 0.47878034]    New: [0.16058647 0.47878034]
# Old: [ 0.48121469 -0.45655899]    New: [ 0.48121469 -0.45655899]
# Old: [-0.71356558  0.3529842 ]    New: [-0.71356558  0.3529842 ]
# Old: [ 0.544056   -0.27523422]    New: [ 0.544056   -0.27523422]
# Old: [0.48050178 0.29933147]    New: [0.48050178 0.29933147]
# Old: [ 0.03017929 -0.37476001]    New: [ 0.03017929 -0.37476001]
# Old: [ 0.05330428 -0.19795388]    New: [ 0.05330428 -0.19795388]
# Old: [-0.37668718 -0.36065365]    New: [-0.37668718 -0.36065365]
# Old: [-0.11832982 -0.13540292]    New: [-0.11832982 -0.13540292]
# Old: [-0.21071293 -0.47498533]    New: [-0.21071293 -0.47498533]
# Old: [0.32681449 0.10781633]    New: [0.32681449 0.10781633]
# Old: [-0.64189917  0.82542376]    New: [-0.91930261  0.50224239]
# Old: [0.20449914 0.06256256]    New: [0.20449914 0.06256256]
# Old: [0.87539324 0.04905822]    New: [ 1.25070377 -0.44008114]
# Old: [-0.04767779  0.61006985]    New: [-0.25437055  0.92451658]
# Old: [-0.5240205  0.3828817]    New: [-0.5240205  0.3828817]
# Old: [-0.654747    0.11850505]    New: [-0.654747    0.11850505]
# Old: [-0.61364341 -0.89255852]    New: [-0.61908269 -1.54765588]
# Old: [-0.23614835  0.15496592]    New: [-0.23614835  0.15496592]
# Old: [-0.53852898 -0.08179722]    New: [-0.53852898 -0.08179722]
# Old: [-0.05092135  0.63071665]    New: [-0.05092135  0.63071665]
# Old: [-0.92249117 -0.18051001]    New: [-0.96600544 -0.7569957 ]
# Old: [0.19153297 0.16252403]    New: [0.19153297 0.16252403]
# Old: [-0.11885266 -1.86792779]    New: [-0.11885266 -1.86792779]

# %%
lowDD = pd.DataFrame()
lowDD["x"] = new_x
lowDD['y'] = new_y
for column in lowD.columns:
    lowDD[column] = (lowDD[column]-lowDD[column].mean())/lowDD[column].std()
lowDD.head()
# Out:
#           x         y
# 0 -0.292311  0.668690
# 1 -0.989006 -0.424775
# 2  1.385241  0.616641
# 3  0.152118 -0.974930
# 4  0.540551  0.963226

# %% [markdown]
# # Reverse lowD to highD

# %%
def proposal(current, step, direction):
    #print("proposal---------------------------------------")
    output = - 1
    if direction == 0:
        output = current - 0.5*step
    elif direction == 1:
        output = current + 0.5*step
    if output >= 0 and output <= 1:
        output = current
    return output

def stress(highDD, lowDD, weight):
    highD = highDD.copy()
    lowD = lowDD.copy()
    #highD = dataHD.copy()

    #print(highD.head())
    #print("stress----------------------------------------")
    #print(lowD.head())
    #print(weight)
    row = len(highD)
    col = len(highD.columns.tolist())
    
    highDSum = 0
    output = 0
    
    tmp_highD = highD.copy()
    for i in range(len(tmp_highD.columns.tolist())):
        tmp_highD.iloc[:, i] = [x*weight[i] for x in tmp_highD.iloc[:, i]]
    #print("stress2----------------------------------------")
    #print(tmp_highD.head())
    new_lowD = cal_distance(tmp_highD)

    #print(new_lowD.shape, lowD.shape)
    # scale lowD sum to 2
    tmp = new_lowD.values.sum()/2
    new_lowD = new_lowD/tmp
    #print(new_lowD.head())
    #print(new_lowD.values.sum(), lowD.values.sum())
    #print(abs(new_lowD.values-lowD.values).sum())
    return abs(new_lowD.values-lowD.values).sum()

def invMDs(highDD, lowDD, weights):
    highD = highDD.copy()
    lowD = lowDD.copy()
    #print(highD.head())
    #print(lowD.head())
    row = len(highD)
    col = len(highD.columns.tolist())    
    flag = [0]*col

    MAX = 50
    
    dummy_weights = []
    for i in range(len(lowD.columns)):
        dummy_weights = dummy_weights + [1/len(lowD.columns)]
    #print(len(dummy_weights), len(lowD.columns))
    #print(dummy_weights)
    #print(lowD.head())
    for i in range(len(lowD.columns)):
        lowD.iloc[:, i] = [x*dummy_weights[i] for x in lowD.iloc[:, i]]
    
    # scale lowD sum to 2
    tmp = lowD.values.sum()/2
    lowD = lowD/tmp
    
    for column in highD.columns:
        highD[column] = (highD[column]-highD[column].mean())/highD[column].std()

    proposedMove = 0
    step = [0]*col
    curWeight = [0]*col
    newWeight = [0]*col

    for i in range(col):
        step[i] = 2.0/col
    
    curWeight = weights
    stressCur = 0
    streeNew = 0
    
    stressCur = stress(highD, lowD, curWeight)
    #print(stressCur)
    #print("1----------------------------------------------------------------")
    for i in range(MAX):
        print("i = ", i)
        direction = 1
        for dim in range(col):
            #print("2-------------------------------------------------------")
            print("round=", i,"  dim=", dim, "  flag[dim]=", flag[dim], "  step[dim]=", step[dim], "  dir=",direction)
            #print("currWeight = ", curWeight)
            newWeight = curWeight
            if flag[dim] >= 5:
                step[dim] = step[dim]*2
                flag[dim] = 0
            elif flag[dim] <= -5:
                step[dim] = step[dim]/2
                flag[dim] = 0
            
           
            newWeight[dim] = proposal(curWeight[dim], step[dim], direction)
            newWeight = [v/sum(newWeight) for v in newWeight]
            print("Current Weight=", curWeight[dim], "  New Weight=", newWeight[dim])
            stressNew = stress(highD, lowD, newWeight)
            #print("newWeight Sum = ", sum(newWeight))
            print("streenew = ", stressNew)
            print("streecur = ", stressCur)
            if stressNew < stressCur:
                curWeight = newWeight
                stressCur = stressNew
                flag[dim] = flag[dim] + 1
            else:
                flag[dim] = flag[dim] - 1
                # change the direction if current stress is less than new stress
                if direction == 0:
                    direction = 1
                elif direction == 1:
                    direction = 0
    print(curWeight)
    return curWeight

# %%
df = pd.read_csv("~/Desktop/Thesis/InfoVis_Fall_2015_Survey.csv")
df = df.set_index('Name')
highDD = df.copy()
weights = [1]*len(highDD)
weights = [x/sum(weights) for x in weights]
result_weights = invMDs(highDD, lowDD, weights)
# Out:
# i =  0
# round= 0   dim= 0   flag[dim]= 0   step[dim]= 0.08   dir= 1
# Current Weight= 0.07030303030303031   New Weight= 0.06759906759906764
# streenew =  5.1946745126697395e+17
# streecur =  1.4640643056644774e+17
# round= 0   dim= 1   flag[dim]= 0   step[dim]= 0.08   dir= 0
# Current Weight= 0.030303030303030304   New Weight= 0.029137529137529157
# streenew =  1.866435480548537e+17
# streecur =  1.4640643056644774e+17
# round= 0   dim= 2   flag[dim]= 0   step[dim]= 0.08   dir= 1
# Current Weight= 0.07030303030303031   New Weight= 0.06509539842873181
# streenew =  1.3093919746964355e+17
# streecur =  1.4640643056644774e+17
# round= 0   dim= 3   flag[dim]= 0   step[dim]= 0.08   dir= 1
# Current Weight= 0.06805836139169474   New Weight= 0.06544073210739877
# streenew =  1.1744108479548418e+17
# streecur =  1.3093919746964355e+17
# round= 0   dim= 4   flag[dim]= 0   step[dim]= 0.08   dir= 1
# Current Weight= 0.
+17
# streecur =  5.8774247891810776e+16
# round= 7   dim= 21   flag[dim]= -2   step[dim]= 0.04   dir= 0
# Current Weight= 0.00917881437945424   New Weight= 0.0057367589871589
# streenew =  9.088380967354188e+17
# streecur =  5.8774247891810776e+16
# round= 7   dim= 22   flag[dim]= -2   step[dim]= 0.04   dir= 1
# Current Weight= 0.06790164046641077   New Weight= 0.041914592880500486
# streenew =  1.2741831166492925e+17
# streecur =  5.8774247891810776e+16
# round= 7   dim= 23   flag[dim]= -2   step[dim]= 0.04   dir= 0
# Current Weight= 0.00917881437945424   New Weight= 0.005665934802132248
# streenew =  1.1408417855615086e+17
# streecur =  5.8774247891810776e+16
# round= 7   dim= 24   flag[dim]= -2   step[dim]= 0.04   dir= 1
# Current Weight= 0.06790164046641077   New Weight= 0.041403439308787066
# streenew =  1.1348117922829317e+17
# streecur =  5.8774247891810776e+16
# i =  8
# round= 8   dim= 0   flag[dim]= -3   step[dim]= 0.04   dir= 1
# Current Weight= 0.18349593631685557   New Weight= 0.11053972067280458
# streenew =  1.655033561639838e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 1   flag[dim]= -3   step[dim]= 0.04   dir= 0
# Current Weight= 0.009178814379454238   New Weight= 0.005529406252683277
# streenew =  2.216274882538924e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 2   flag[dim]= -1   step[dim]= 0.04   dir= 1
# Current Weight= 0.22349593631685558   New Weight= 0.13303329542669978
# streenew =  1.1975321687873694e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 3   flag[dim]= -1   step[dim]= 0.04   dir= 0
# Current Weight= 0.005280436506630281   New Weight= 0.0031431169682323104
# streenew =  1.150055476020251e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 4   flag[dim]= -4   step[dim]= 0.08   dir= 1
# Current Weight= 0.26498863182649995   New Weight= 0.15406315803866277
# streenew =  2.275811060246994e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 5   flag[dim]= -3   step[dim]= 0.04   dir= 0
# Current Weight= 0.0015927636548165448   New Weight= 0.0009260253807072936
# streenew =  1.2103524742249198e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 6   flag[dim]= -3   step[dim]= 0.04   dir= 1
# Current Weight= 0.15439620568380208   New Weight= 0.088733451542415
# streenew =  2.2984963954692653e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 7   flag[dim]= -3   step[dim]= 0.04   dir= 0
# Current Weight= 0.0015927636548165448   New Weight= 0.0009153814108141064
# streenew =  1.268554899851124e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 8   flag[dim]= -1   step[dim]= 0.04   dir= 1
# Current Weight= 0.19439620568380206   New Weight= 0.11045238959306938
# streenew =  1.198896262891904e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 9   flag[dim]= -3   step[dim]= 0.04   dir= 0
# Current Weight= 0.0015927636548165452   New Weight= 0.0009049793493275828
# streenew =  inf
# streecur =  5.8774247891810776e+16
# round= 8   dim= 10   flag[dim]= -3   step[dim]= 0.04   dir= 1
# Current Weight= 0.09265707524901948   New Weight= 0.052054536656752526
# streenew =  inf
# streecur =  5.8774247891810776e+16
# round= 8   dim= 11   flag[dim]= -3   step[dim]= 0.04   dir= 0
# Current Weight= 0.0015927636548165452   New Weight= 0.0008948110420317672
# streenew =  1.5448318297089302e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 12   flag[dim]= -3   step[dim]= 0.04   dir= 1
# Current Weight= 0.09265707524901948   New Weight= 0.051476152916121946
# streenew =  1.1805875113103011e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 13   flag[dim]= -3   step[dim]= 0.04   dir= 0
# Current Weight= 0.0015927636548165452   New Weight= 0.0008848686971203031
# streenew =  1.1656201043298083e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 14   flag[dim]= -1   step[dim]= 0.04   dir= 1
# Current Weight= 0.13265707524901946   New Weight= 0.07288850288407664
# streenew =  9.835962639770362e+16
# streecur =  5.8774247891810776e+16
# round= 8   dim= 15   flag[dim]= -3   step[dim]= 0.04   dir= 0
# Current Weight= 0.00917881437945424   New Weight= 0.005043304604095737
# streenew =  1.9100709213518077e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 16   flag[dim]= -3   step[dim]= 0.04   dir= 1
# Current Weight= 0.08790164046641077   New Weight= 0.04777263068826673
# streenew =  1.5651721689243446e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 17   flag[dim]= -3   step[dim]= 0.04   dir= 0
# Current Weight= 0.00917881437945424   New Weight= 0.004988486075790348
# streenew =  1.5716094802055734e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 18   flag[dim]= -3   step[dim]= 0.04   dir= 1
# Current Weight= 0.08790164046641077   New Weight= 0.04725894648731763
# streenew =  1.4274470333830539e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 19   flag[dim]= -3   step[dim]= 0.04   dir= 0
# Current Weight= 0.00917881437945424   New Weight= 0.004934846440566796
# streenew =  2.8440409334878365e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 20   flag[dim]= -3   step[dim]= 0.04   dir= 1
# Current Weight= 0.08790164046641077   New Weight= 0.046756191737452546
# streenew =  1.197904234628697e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 21   flag[dim]= -3   step[dim]= 0.04   dir= 0
# Current Weight= 0.00917881437945424   New Weight= 0.004882348074177788
# streenew =  1.4926869522095485e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 22   flag[dim]= -3   step[dim]= 0.04   dir= 1
# Current Weight= 0.08790164046641077   New Weight= 0.04626402129811094
# streenew =  1.5591988639930602e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 23   flag[dim]= -3   step[dim]= 0.04   dir= 0
# Current Weight= 0.00917881437945424   New Weight= 0.004830954936554863
# streenew =  1.389905869098707e+17
# streecur =  5.8774247891810776e+16
# round= 8   dim= 24   flag[dim]= -3   step[dim]= 0.04   dir= 1
# Current Weight= 0.08790164046641077   New Weight= 0.04578210440958895
# streenew =  inf
# streecur =  5.8774247891810776e+16
# i =  9
# round= 9   dim= 0   flag[dim]= -4   step[dim]= 0.04   dir= 1
# Current Weight= 0.20349593631685556   New Weight= 0.10489481253446165
# streenew =  1.765770717199801e+17
# streecur =  5.8774247891810776e+16
# round= 9   dim= 1   flag[dim]= -4   step[dim]= 0.04   dir= 0
# Current Weight= 0.009178814379454238   New Weight= 0.004731347618275381
# streenew =  9.854133617111248e+16
# streecur =  5.8774247891810776e+16
# round= 9   dim= 2   flag[dim]= -2   step[dim]= 0.04   dir= 1
# Current Weight= 0.24349593631685557   New Weight= 0.12423262056982429
# streenew =  1.824962572904647e+17
# streecur =  5.8774247891810776e+16
# round= 9   dim= 3   flag[dim]= -2   step[dim]= 0.04   dir= 0
# Current Weight= 0.005280436506630281   New Weight= 0.0026941002584848373
# streenew =  9.317112677244674e+16
# streecur =  5.8774247891810776e+16
# round= 9   dim= 4   flag[dim]= -5   step[dim]= 0.08   dir= 1
# Current Weight= 0.28498863182649997   New Weight= 0.14393365243762626
# streenew =  1.1488343849355032e+17
# streecur =  5.8774247891810776e+16
# round= 9   dim= 5   flag[dim]= -4   step[dim]= 0.04   dir= 0
# Current Weight= 0.0015927636548165448   New Weight= 0.0008044260882911844
# streenew =  1.6416208695207142e+17
# streecur =  5.8774247891810776e+16
# round= 9   dim= 6   flag[dim]= -4   step[dim]= 0.04   dir= 1
# Current Weight= 0.17439620568380207   New Weight= 0.08719810284190105
# streenew =  1.622610360102331e+17
# streecur =  5.8774247891810776e+16
# round= 9   dim= 7   flag[dim]= -4   step[dim]= 0.04   dir= 0
# Current Weight= 0.0015927636548165448   New Weight= 0.0007963818274082725
# streenew =  1.221580799337421e+17
# streecur =  5.8774247891810776e+16
# round= 9   dim= 8   flag[dim]= -2   step[dim]= 0.04   dir= 1
# Current Weight= 0.21439620568380205   New Weight= 0.10613673548703069
# streenew =  1.2917612958271221e+17
# streecur =  5.8774247891810776e+16
# round= 9   dim= 9   flag[dim]= -4   step[dim]= 0.04   dir= 0
# Current Weight= 0.0015927636548165452   New Weight= 0.0007884968588200718
# streenew =  1.1108257153520333e+17
# streecur =  5.8774247891810776e+16
# round= 9   dim= 10   flag[dim]= -4   step[dim]= 0.04   dir= 1
# Current Weight= 0.11265707524901948   New Weight= 0.05522405649461737
# streenew =  2.6104831554677667e+17
# streecur =  5.8774247891810776e+16
# round= 9   dim= 11   flag[dim]= -4   step[dim]= 0.04   dir= 0
# Current Weight= 0.0015927636548165452   New Weight= 0.0007807664974590904
# streenew =  1.660933000410273e+17
# streecur =  5.8774247891810776e+16
# round= 9   dim= 12   flag[dim]= -4   step[dim]= 0.04   dir= 1
# Current Weight= 0.11265707524901948   New Weight= 0.0546879006063201
# streenew =  1.7922098188330195e+17
# streecur =  5.8774247891810776e+16
# round= 9   dim= 13   flag[dim]= -4   step[dim]= 0.04   dir= 0
# Current Weight= 0.0015927636548165452   New Weight= 0.0007731862402022059
# streenew =  1.064041844398497e+17
# streecur =  5.8774247891810776e+16
# round= 9   dim= 14   flag[dim]= -2   step[dim]= 0.04   dir= 1
# Current Weight= 0.15265707524901945   New Weight= 0.07339282463895161
# streenew =  4.539797367937897e+17
# streecur =  5.8774247891810776e+16
# ...
# round= 47   dim= 2   flag[dim]= -5   step[dim]= 0.0003125   dir= 1
# Current Weight= 0.38279281131685555   New Weight= 0.10623450814916414
# streenew =  2.1795247468428803e+17
# streecur =  5.8774247891810776e+16
# round= 47   dim= 3   flag[dim]= -5   step[dim]= 0.0003125   dir= 0
# Current Weight= 4.6061506630280485e-05   New Weight= 1.2783488754961729e-05
# streenew =  1.2117095816770658e+17
# streecur =  5.8774247891810776e+16
# round= 47   dim= 4   flag[dim]= -3   step[dim]= 0.0003125   dir= 1
# Current Weight= 0.4640511318265   New Weight= 0.12878291714283974
# streenew =  2.5494678817516698e+17
# streecur =  5.8774247891810776e+16
# round= 47   dim= 5   flag[dim]= -2   step[dim]= 0.00015625   dir= 0
# Current Weight= 3.0263654816544783e-05   New Weight= 8.398733422625871e-06
# streenew =  4.880136745364454e+17
# streecur =  5.8774247891810776e+16
# round= 47   dim= 6   flag[dim]= -2   step[dim]= 0.00015625   dir= 1
# Current Weight= 0.27384933068380196   New Weight= 0.07599669223728782
# streenew =  2.454305053318978e+17
# streecur =  5.8774247891810776e+16
# round= 47   dim= 7   flag[dim]= -2   step[dim]= 0.00015625   dir= 0
# Current Weight= 3.0263654816544783e-05   New Weight= 8.398551332316647e-06
# streenew =  1.6720187661321075e+17
# streecur =  5.8774247891810776e+16
# round= 47   dim= 8   flag[dim]= -5   step[dim]= 0.0003125   dir= 1
# Current Weight= 0.353693080683802   New Weight= 0.0981522261843396
# streenew =  1.4374717010823114e+17
# streecur =  5.8774247891810776e+16
# round= 47   dim= 9   flag[dim]= -2   step[dim]= 0.00015625   dir= 0
# Current Weight= 3.0263654816545217e-05   New Weight= 8.398369249903059e-06
# streenew =  1.5141635051103837e+17
# streecur =  5.8774247891810776e+16
# round= 47   dim= 10   flag[dim]= -2   step[dim]= 0.00015625   dir= 1
# Current Weight= 0.21211020024901947   New Weight= 0.05886074151644296
# streenew =  7.270672052716058e+16
# streecur =  5.8774247891810776e+16
# round= 47   dim= 11   flag[dim]= -2   step[dim]= 0.00015625   dir= 0
# Current Weight= 3.0263654816545217e-05   New Weight= 8.398187175384351e-06
# streenew =  inf
# streecur =  5.8774247891810776e+16
# round= 47   dim= 12   flag[dim]= -2   step[dim]= 0.00015625   dir= 1
# Current Weight= 0.21211020024901947   New Weight= 0.05885946545813619
# streenew =  1.949286370506431e+17
# streecur =  5.8774247891810776e+16
# round= 47   dim= 13   flag[dim]= -2   step[dim]= 0.00015625   dir= 0
# Current Weight= 3.0263654816545217e-05   New Weight= 8.398005108760132e-06
# streenew =  1.1393738134137232e+17
# streecur =  5.8774247891810776e+16
# round= 47   dim= 14   flag[dim]= -5   step[dim]= 0.0003125   dir= 1
# Current Weight= 0.2919539502490194   New Weight= 0.08101393000319647
# streenew =  1.2191161673866104e+17
# streecur =  5.8774247891810776e+16
# round= 47   dim= 15   flag[dim]= -2   step[dim]= 0.00015625   dir= 0
# Current Weight= 3.818937945423909e-05   New Weight= 1.0597122290458293e-05
# streenew =  4.5541809919779206e+17
# streecur =  5.8774247891810776e+16
# round= 47   dim= 16   flag[dim]= -2   step[dim]= 0.00015625   dir= 1
# Current Weight= 0.